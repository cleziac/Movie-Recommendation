# %% [markdown]
# <a href="https://colab.research.google.com/github/cleziac/Movie-Recommendation/blob/main/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import numpy as np

# %%
path = '/content/drive/MyDrive/data'

# %%
data1 = pd.read_csv(path + '/tmdb_5000_movies.csv',
                    low_memory = False)

# %%
data1.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data2 = pd.read_csv(path + '/tmdb_5000_credits.csv', low_memory = False)

# %%
data2.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
data1.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
data2.rename(columns= {'movie_id' : 'id'}, inplace = True)

# %%
data2.drop('title', axis = 1, inplace = True)

# %%
data_movies = pd.merge(data1, data2, on = 'id')

data_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
data_movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
data_movies.isna().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                       0
# crew                       0
# dtype: int64

# %%
data_movies.loc[0]
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
data_movies.drop(['budget', 'homepage', 'tagline', 'runtime', 'revenue', 'status',
                  'spoken_languages', 'original_title', 'production_companies', 'production_countries'],
                 axis = 1,
                 inplace = True)

# %%
data_movies.head(5)
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
links = pd.read_csv(path + '/links.csv')

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links.tmdbId = links.tmdbId.astype('int', errors = 'ignore')

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
data_movies.loc[data_movies.id == 862]
# Out:
#                                                  genres   id  \
# 1541  [{"id": 16, "name": "Animation"}, {"id": 35, "...  862
#
#                                                keywords original_language  \
# 1541  [{"id": 931, "name": "jealousy"}, {"id": 4290,...                en
#
#                                                overview  popularity  \
# 1541  Led by Woody, Andy's toys live happily in his ...   73.640445
#
#      release_date      title  vote_average  vote_count  \
# 1541   1995-10-30  Toy Story           7.7        5269
#
#                                                    cast  \
# 1541  [{"cast_id": 14, "character": "Woody (voice)",...
#
#                                                    crew
# 1541  [{"credit_id": "52fe4284c3a36847f8024f55", "de...

# %%
links.rename(columns = {'tmdbId' : 'id'}, inplace = True)

# %%
data_movies_linked = pd.merge(data_movies, links, on = 'id')

# %%
data_movies_linked
# Out:
#                                                  genres      id  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...                                                 ...     ...
# 4594  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4595  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4596  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4597                                                 []  126186
# 4598                [{"id": 99, "name": "Documentary"}]   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# ...

# %%
posters_df = pd.read_csv(path + '/MovieGenre.csv', encoding='latin-1')

posters_df.head(5)
# Out:
#    imdbId                           Imdb Link  \
# 0  114709  http://www.imdb.com/title/tt114709
# 1  113497  http://www.imdb.com/title/tt113497
# 2  113228  http://www.imdb.com/title/tt113228
# 3  114885  http://www.imdb.com/title/tt114885
# 4  113041  http://www.imdb.com/title/tt113041
#
#                                 Title  IMDB Score                       Genre  \
# 0                    Toy Story (1995)         8.3  Animation|Adventure|Comedy
# 1                      Jumanji (1995)         6.9     Action|Adventure|Family
# 2             Grumpier Old Men (1995)         6.6              Comedy|Romance
# 3            Waiting to Exhale (1995)         5.7        Comedy|Drama|Romance
# 4  Father of the Bride Part II (1995)         5.9       Comedy|Family|Romance
#
#                                               Poster
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# ...

# %%
df = pd.merge(data_movies_linked, posters_df, on = 'imdbId')

# %%
df.head()
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                                             overview  popularity release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577   2009-12-10
# ...

# %%
df.columns
# Out:
# Index(['genres', 'id', 'keywords', 'original_language', 'overview',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count',
#        'cast', 'crew', 'movieId', 'imdbId', 'Imdb Link', 'Title', 'IMDB Score',
#        'Genre', 'Poster'],
#       dtype='object')

# %%
df.drop(['id', 'movieId', 'imdbId', 'Imdb Link', 'genres', 'IMDB Score'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                                             overview  popularity release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577   2009-12-10
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615   2007-05-19
# 2  A cryptic message from Bond’s past sends him o...  107.376788   2015-10-26
# 3  Following the death of District Attorney Harve...  112.312950   2012-07-16
# 4  John Carter is a war-weary, former military ca...   43.926995   2012-03-07
#
# ...

# %%
# df['Name'] = df['Name'].str.extract('\[(.*?)\]', expand=False)

df['year'] = df['Title'].str.extract('\((.*?)\)')

df.head(2)
# Out:
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                                             overview  popularity release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577   2009-12-10
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615   2007-05-19
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# ...

# %%
# df['posttext'].str.contains("?", regex=False)

# %%
df.loc[df['title'].str.contains('?', regex = False)]
# Out:
#                                                keywords original_language  \
# 812   [{"id": 4009, "name": "witness protection"}, {...                en
# 1016  [{"id": 3767, "name": "noises"}, {"id": 4862, ...                en
# 1205  [{"id": 931, "name": "jealousy"}, {"id": 1157,...                en
# 1648  [{"id": 4480, "name": "business man"}, {"id": ...                en
# 1828  [{"id": 530, "name": "prophecy"}, {"id": 531, ...                en
# 2142  [{"id": 1926, "name": "car journey"}, {"id": 2...                en
# 2152                                                 []                en
# 2246  [{"id": 818, "name": "based on novel"}, {"id":...                en
# 2584                                                 []                en
# 2585                                                 []                en
# 2790  [{"id": 419, "name": "dude"}, {"id": 1453, "na...                en
# 3333  [{"id": 494, "name": "father son relationship"...                en
# ...

# %%
df.drop('release_date', axis = 1, inplace = True)

# %%
df.isna().sum()
# Out:
# keywords             0
# original_language    0
# overview             1
# popularity           0
# title                0
# vote_average         0
# vote_count           0
# cast                 0
# crew                 0
# Title                0
# Genre                0
# Poster               0
# year                 5
# dtype: int64

# %%
len(df)
# Out:
# 4693

# %%
df.to_csv(path + '/df_def.csv')

# %%
test = df[:10]

test
# Out:
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5  [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 6  [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# 7  [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 8  [{"id": 616, "name": "witch"}, {"id": 2343, "n...                en
# 9  [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
df.sort_values(by = 'title', ascending = True)
# Out:
#                                                keywords original_language  \
# 4264                                                 []                de
# 3394  [{"id": 248, "name": "date"}, {"id": 572, "nam...                en
# 3610  [{"id": 1930, "name": "kidnapping"}, {"id": 23...                en
# 2794  [{"id": 497, "name": "shakespeare"}, {"id": 59...                en
# 405   [{"id": 212, "name": "london england"}, {"id":...                en
# ...                                                 ...               ...
# 3578  [{"id": 3684, "name": "religion and supernatur...                es
# 2129  [{"id": 282, "name": "video game"}, {"id": 215...                en
# 583   [{"id": 999, "name": "sports car"}, {"id": 186...                en
# 781   [{"id": 521, "name": "washington d.c."}, {"id"...                en
# 872   [{"id": 779, "name": "martial arts"}, {"id": 4...                en
#
#                                                overview  popularity  \
# ...

# %%
test.Poster
# Out:
# 0    https://images-na.ssl-images-amazon.com/images...
# 1    https://images-na.ssl-images-amazon.com/images...
# 2    https://images-na.ssl-images-amazon.com/images...
# 3    https://images-na.ssl-images-amazon.com/images...
# 4    https://images-na.ssl-images-amazon.com/images...
# 5    https://images-na.ssl-images-amazon.com/images...
# 6    https://images-na.ssl-images-amazon.com/images...
# 7    https://images-na.ssl-images-amazon.com/images...
# 8    https://images-na.ssl-images-amazon.com/images...
# 9    https://images-na.ssl-images-amazon.com/images...
# Name: Poster, dtype: object

# %%
test.to_csv(path + '/test_dataset.csv')

# %%
limited = df[['title', 'Poster']]

# %%
lim = limited[:2]

# %%
url_list = list(limited['Poster'])
name_list = list(limited['Title'])

# %%
import sys

# %%
df.loc[df['title'].str.contains(u'/')]
# Out:
#                                                keywords original_language  \
# 456   [{"id": 1568, "name": "undercover"}, {"id": 16...                en
# 1720  [{"id": 1925, "name": "camera"}, {"id": 2251, ...                en
# 1847  [{"id": 2251, "name": "lie"}, {"id": 4978, "na...                en
# 2414  [{"id": 459, "name": "sexual obsession"}, {"id...                en
# 2813  [{"id": 725, "name": "lovesickness"}, {"id": 9...                en
# 3300  [{"id": 437, "name": "painter"}, {"id": 494, "...                en
# 3502  [{"id": 840, "name": "usa president"}, {"id": ...                en
#
#                                                overview  popularity  \
# 456   An antiterrorism agent goes under the knife to...   46.075037
# 1720  For three years after being forced from office...   16.877840
# 1847  An extremely wealthy elderly man dying from ca...   66.097437
# 2414  An erotic story about a woman, the assistant o...   12.313143
# ...

# %% [markdown]
# Index to delete:
#
# 456
#
# 1720
#
# 1847
#
# 2414
#
# 2813
#
# 3300
#
# 3502

# %%
df1 = df.drop([456, 1720, 1847, 2414, 2813, 3300, 3502])

df1.head()
# Out:
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/data/to_use.csv')

df
# Out:
#       Unnamed: 0                                           keywords  \
# 0              0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1              1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2              2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3              3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4              4  [{"id": 818, "name": "based on novel"}, {"id":...
# ...          ...                                                ...
# 4681        4688  [{"id": 5616, "name": "united states\u2013mexi...
# 4682        4689                                                 []
# 4683        4690  [{"id": 248, "name": "date"}, {"id": 699, "nam...
# 4684        4691                                                 []
# 4685        4692  [{"id": 1523, "name": "obsession"}, {"id": 224...
#
#      original_language                                           overview  \
# 0                   en  In the 22nd century, a paraplegic Marine is di...
# ...

# %%
import urllib3
http = urllib3.PoolManager()

urls = list(df['Poster'])
names = list(df['title'])
N = 0 # counter helps me to rename the downloaded files
# print "downloading with urllib"
for url in urls:
    r = http.request('GET',url)
    Name =str(N+1)
    N += 1
    #print(names[N - 1])
    with open("/content/drive/MyDrive/data/posters/" + names[N-1] + ".jpg", "wb") as fcont:
       fcont.write(r.data)

# %%
df.head()
# Out:
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# ...

# %%
df[['title']].sort_values(by = 'title', ascending = True).to_csv('/content/drive/MyDrive/data/ordered_by_title.csv')
